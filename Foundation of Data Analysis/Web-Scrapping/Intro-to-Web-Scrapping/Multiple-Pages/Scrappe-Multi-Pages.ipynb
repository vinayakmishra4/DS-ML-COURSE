# %% [markdown]
# # Scrapping Multiple Pages

# %% [raw]
# Now we will scrappe multiple pages of the website. We will use the same code as before, but we will add a loop to go through the pages.

# %% [markdown]
# ## Step 1: Fetch One Page First

# %%
import requests
from bs4 import BeautifulSoup
# suppress warnings about unverified HTTPS requests
import urllib3

# Disable warnings about unverified HTTPS requests
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

url = "https://example.com/page=1"
headers = {"User-Agent": "Mozilla/5.0"}

# add the verify=False parameter to the get request to ignore SSL certificate verification
response = requests.get(url, headers=headers, verify=False)

soup = BeautifulSoup(response.text, "html.parser")
print(soup.title.text)
# Out:
# Example Domain

# %% [markdown]
# ## Step 2: Extract Data from One Page

# %%
items = soup.find_all("h2")  # change this!

# print the text of each item
for item in items:
    print(item.text.strip())

# %% [markdown]
# # Step 3: Loop Through Multiple Pages

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
headers ={"User-Agent": "Mozilla/5.0"}
base_url = "https://books.toscrape.com/catalogue/page-{}.html"

# loop through pages 1 to 5
# Note: Adjust the range as needed based on the actual number of pages available
for page in range(1, 6):
    url = base_url.format(page)
    print(f"Scraping page {page}...")
    response = requests.get(url, headers=headers, verify=False)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        items = soup.find_all("h2")  # change selector
        for item in items:
            print(item.text.strip())
    else:
        print("Failed:", url)
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Scraping page 4...
# Scraping page 5...

# %% [markdown]
# ## Step 7: Store Data

# %%
# Now let's store the data in a list instead of printing it
data = []
for page in range(1, 6):
    url = base_url.format(page)
    
    print(f"\nScraping page {page}...")

    response = requests.get(url, headers=headers, verify=False)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        
        books = soup.find_all("h3")
        
        for book in books:
            title = book.find("a")["title"]   # ✅ correct extraction
            data.append(title)
    else:
        print("Failed:", url)
# Finally, we can print the collected data
print(data)
# Out:
# Scraping page 1...
#
# Scraping page 2...
#
# Scraping page 3...
#
# Scraping page 4...
#
# Scraping page 5...
# ...
