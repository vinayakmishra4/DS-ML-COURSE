# %% [markdown]
# # Selenium

# %% [raw]
# Selenium is automation tool for web applications. It provides a suite of tools and libraries that allow developers and testers to automate web browsers. Selenium supports multiple programming languages, including Java, Python, C#, Ruby, and JavaScript, making it versatile for various testing needs.

# %%
# import libraries
from selenium import webdriver
import chromedriver_binary
driver=webdriver.Chrome()
chromedriver_binary.chromedriver_filename
# Out:
# 'c:\\Users\\Nbinary\\AppData\\Local\\Python\\pythoncore-3.14-64\\Lib\\site-packages\\chromedriver_binary\\chromedriver.exe'
