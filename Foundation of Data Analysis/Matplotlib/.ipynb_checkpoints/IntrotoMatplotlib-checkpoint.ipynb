# %% [markdown]
# # INTRODUCTION TO MATPLOTLIB

# %%
# import the matplotlib libaraies 
import matplotlib as mp
import numpy as np
import pandas as pd

# %% [markdown]
# ## Genrating the Sine and Cosine Graph

# %%
mp.l
