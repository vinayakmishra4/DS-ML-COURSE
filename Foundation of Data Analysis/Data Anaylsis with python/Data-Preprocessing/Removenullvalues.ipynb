# %%
import pandas as pd

# %% [markdown]
# # LOAD DATASET

# %%
df=pd.read_csv('googleplaystore.csv')

# %%
data=pd.DataFrame(df)

# %% [markdown]
# # Check the Null Values

# %%
# isnull() function will tell whether null values is there or not
# sum() this function add all the null values and print 
data.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64
