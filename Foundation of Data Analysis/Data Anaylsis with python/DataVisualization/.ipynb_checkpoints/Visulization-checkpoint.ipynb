# %% [markdown]
# # DATA VISUALIZATION

# %% [raw]
# Clean the dataset before visualization of googleplaystore dataset

# %%
# import the libaraies
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as pt
from sklearn.impute import SimpleImputer

# %%
# Load the dataset now
df=pd.read_csv('googleplaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Remove or alter the null data in dataset
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [raw]
# alter null values in the dataset beause the percentage is 13.7%

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy="mean")
imputer.fit(df[['Rating']])
df['Rating']=imputer.transform(df[['Rating']])

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df.isnull().sum().mean()
# Out:
# np.float64(1.0)

# %%
df.dropna(inplace=True)

# %% [raw]
# There is no null values now in the dataset Now we handle the datatype
# check that datatype of colummuns are correct or not
# if no correct then change the datatype

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Remove $ and convert to float
df['Price'] = df['Price'].replace('[\$,]', '', regex=True).astype(float)

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.rename(columns={'Price':'Price($)'}, inplace=True)

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price($)          float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
df.drop_duplicates(inplace=True)

# %% [raw]
# now we have handled the duplicate values now last thing which we handle is outliers in dataset
# In this dataset has also outliers but we will not remove so that we can analysis on real world

# %% [raw]
# Now the Dataset is ready for the Visuizaltion

# %% [markdown]
# # UNIVARIATE VISUZALIZATION
