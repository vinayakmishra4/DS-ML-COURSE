# %% [markdown]
# # Remove the Dupilcate Data

# %%
# import libaras essential from reomved
import numpy as np
import pandas as pd

# %%
# read the dataset and convert it into dataframe
df=pd.read_csv('googleplaystore.csv')

# %%
df.shape
# Out:
# (10841, 13)

# %%
# it will give total number of duplicate rows in the dataframe
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
#Remove duplicate rows from the dataframe
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (10358, 13)

# %% [raw]
# before removeing  duplicate rows and after removing duplicate rows.shape is (10841, 13)
# after removeing duplicate rows.shape is (10358, 13)
# duplicate rows removed are 483
